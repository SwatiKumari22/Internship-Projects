# %% [markdown]
# # Installing Selenium

# %%
#Let's first install selenium
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\data_science\lib\site-packages (4.1.3)
# Requirement already satisfied: trio~=0.17 in c:\data_science\lib\site-packages (from selenium) (0.20.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\data_science\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: trio-websocket~=0.9 in c:\data_science\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sortedcontainers in c:\data_science\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: outcome in c:\data_science\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\data_science\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: async-generator>=1.9 in c:\data_science\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\data_science\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\data_science\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: idna in c:\data_science\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: pycparser in c:\data_science\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\data_science\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\data_science\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: certifi in c:\data_science\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: cryptography>=1.3.4 in c:\data_science\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\data_science\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: six>=1.5.2 in c:\data_science\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\data_science\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
#Lets import all the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import time

#Importing requests
import requests

# importing regex
import re

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#Lets connect to the web driver
driver=webdriver.Chrome(r"C:\Users\X1\chromedriver_win32\chromedriver.exe")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
#Getting amazon page
driver.get('https://www.amazon.in/')
#Giving input
search_item= input('Enter the product that has to be searched : ')
# Out:
# Enter the product that has to be searched : Guitar

# %%
# Searching the web element for user input
search = driver.find_element_by_id("twotabsearchtextbox")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2f0da0ca9244a2cca8278083cd63c1e5", element="bf19345d-66df-4ed9-a872-2dfce8657879")>

# %%
# Sending the user input to search bar
search.send_keys(search_item)

# %%
# Locating the search button using xpath
search_btn = driver.find_element_by_xpath("//div[@class='nav-search-submit nav-sprite']/span/input")
# Clicking on search button
search_btn.click()

# %% [markdown]
# ## Q2: In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical hasless than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. ofRatings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"and “Product URL”. In case, if any of the details are missing for any of the product then replace it by "-"

# %%
# Fetching URLs to open the pages
urls = []    # Empty list
for i in range(0,3):   # for loop to scrape 3 pages
    page_url = driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
    for i in page_url:
        urls.append(i.get_attribute("href"))
    
     #next button 
    nxt_btn=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']") 
    url=nxt_btn.get_attribute('href')
    driver.get(url)
    time.sleep(2)

# %%
len(urls)
# Out:
# 173

# %%
Brand_Name = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    try:
        brand = driver.find_element_by_xpath("//a[@id='bylineInfo']")
        Brand_Name.append(brand.text)
    except NoSuchElementException:
        Brand_Name.append('-')

# %%
len(Brand_Name)
# Out:
# 173

# %%
time.sleep(2)
# Extracting Name of the Product
Product_Name = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        name = driver.find_element_by_xpath("//span[@id='productTitle']")
        Product_Name.append(name.text)
    except NoSuchElementException:
        Product_Name.append('-')

# %%
len(Product_Name)
# Out:
# 173

# %%
time.sleep(2)
# Extracting Rating of the product
Rating = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        ratings = driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']/span")
        Rating.append(ratings.text)
    except NoSuchElementException:
        Rating.append('-')

# %%
len(Rating)
# Out:
# 173

# %%
time.sleep(2)
# Extracting No. of Ratings
No_of_Ratings = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        no_of_ratings = driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        No_of_Ratings.append(no_of_ratings.text)
    except NoSuchElementException:
        No_of_Ratings.append('-')

# %%
len(No_of_Ratings)
# Out:
# 173

# %%
time.sleep(2)
# Extracting Price of the product
Price = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        price = driver.find_element_by_xpath("//td[@class='a-span12']")
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')

# %%
len(Price)
# Out:
# 173

# %%
time.sleep(2)
# Extracting the Return/Exchange of the product
Exchange = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        Return = driver.find_element_by_xpath("//span[@class='a-declarative']/div/a")
        Exchange.append(Return.text)
    except NoSuchElementException:
        Exchange.append('-')

# %%
len(Exchange)
# Out:
# 173

# %%
time.sleep(2)
# Extracting the Expected Delivery of the product
Expected_delivery = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        exp_del = driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
        Expected_delivery.append(exp_del.text)
    except NoSuchElementException:
        Expected_delivery.append('-')

# %%
len(Expected_delivery)
# Out:
# 173

# %%
time.sleep(2)
# Extracting Availability of the product
Availability = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        availability = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-success']")
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')

# %%
len(Availability)
# Out:
# 173

# %%
time.sleep(2)
# Extracting Other Details of the product
Other_Details = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        other_details = driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']")
        Other_Details.append(other_details.text)
    except NoSuchElementException:
        Other_Details.append('-')

# %%
len(Other_Details)
# Out:
# 173

# %%
print(len(Brand_Name),len(Product_Name),len(Rating),len(No_of_Ratings),len(Price),len(Exchange),len(Expected_delivery),len(Availability),len(Other_Details),len(urls))
# Out:
# 173 173 173 173 173 173 173 173 173 173

# %%
# Creating the DataFrame for the scraped data

Product = pd.DataFrame({})
Product["Brand Name"] = Brand_Name
Product["Product Name"] = Product_Name
Product["Rating"] = Rating
Product["No Of Ratings"] = No_of_Ratings
Product["Price"] = Price
Product["Return/Exchange"] = Exchange
Product["Expected Delivery"] = Expected_delivery
Product["Availability"] = Availability
Product["Other Details"] = Other_Details
Product["Product URL"] = urls
Product
# Out:
#                     Brand Name  \
# 0      Visit the Kadence Store
# 1      Visit the Kadence Store
# 2        Visit the VAULT Store
# 3    Visit the blueberry Store
# 4       Visit the JUAREZ Store
# ..                         ...
# 168             Brand: Granada
# 169     Visit the GIVSUN Store
# 170     Visit the Intern Store
# 171           Brand: KETOSTICS
# 172        Brand: Martin Smith
#
#                                           Product Name        Rating  \
# 0    Kadence Frontier guitar with Online Guitar lea...    4 out of 5
# 1    Kadence Frontier Jumbo Semi Acoustic Guitar Wi...    4 out of 5
# 2    Vault Traveller 34 Inch Acoustic Guitar With B...  3.9 out of 5
# 3    Blueberry 38C, 38" Acoustic Guitar Kit with Ba...  3.8 out of 5
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...    4 out of 5
# ..                                                 ...           ...
# 168  Granada, Acoustic Guitar, Dreadnought PRLD-14C...    4 out of 5
# 169  Givsun Crown Special (Black Matt) 6-string Cut...  4.2 out of 5
# 170  Intern INT-38C Natural Acoustic Guitar kit wit...  3.8 out of 5
# 171  Ketostics Givson Venus Special Cutaway Rosewoo...    3 out of 5
# 172  Martin Smith W-101-N-PK Acoustic Guitar Super ...  4.3 out of 5
#
#       No Of Ratings      Price     Return/Exchange Expected Delivery  \
# 0     1,481 ratings  ₹5,399.00  7 Days Replacement                 -
# 1     1,214 ratings  ₹7,348.00  7 Days Replacement                 -
# 2       342 ratings          -  7 Days Replacement                 -
# 3        14 ratings          -  7 Days Replacement                 -
# 4    15,861 ratings          -  7 Days Replacement                 -
# ..              ...        ...                 ...               ...
# 168        1 rating          -  7 Days Replacement                 -
# 169       3 ratings          -  7 Days Replacement                 -
# 170   1,881 ratings          -  7 Days Replacement                 -
# 171        1 rating          -  7 Days Replacement                 -
# 172   4,068 ratings          -  7 Days Replacement                 -
#
#     Availability                                      Other Details  \
# 0              -  ★ Design - The High Gloss finish, Simple head ...
# 1              -  QUALITY STRINGS ---The surface is coated with ...
# 2              -  Size: 34" Steel stringed | Number of Strings: ...
# 3              -  Material: Top: linden wood, Side & Back: - lin...
# 4              -  Black Glossy Finish, Number of Frets: 18, Acou...
# ..           ...                                                ...
# 168            -  Linden Laminated Body\nComposite Rosewood Fing...
# 169            -  Acoustic 40 Inch Steel String Guitar With Trus...
# 170            -  Great looks with an innovative design to produ...
# 171            -  Venus Special 6 Strings | Acoustic Guitar | Co...
# 172            -  Steel strung full scale neck\nSlim line contou...
#
#                                            Product URL
# 0    https://www.amazon.in/gp/slredirect/picassoRed...
# 1    https://www.amazon.in/gp/slredirect/picassoRed...
# 2    https://www.amazon.in/gp/slredirect/picassoRed...
# 3    https://www.amazon.in/gp/slredirect/picassoRed...
# 4    https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..                                                 ...
# 168  https://www.amazon.in/Granada-Acoustic-Dreadno...
# 169  https://www.amazon.in/Special-6-string-Acousti...
# 170  https://www.amazon.in/Intern-INT-38C-Natural-A...
# 171  https://www.amazon.in/Ketostics-Rosewood-Acous...
# 172  https://www.amazon.in/Martin-Smith-W-101-N-PK-...
#
# [173 rows x 10 columns]

# %%
Product.head()
# Out:
#                   Brand Name  \
# 0    Visit the Kadence Store
# 1    Visit the Kadence Store
# 2      Visit the VAULT Store
# 3  Visit the blueberry Store
# 4     Visit the JUAREZ Store
#
#                                         Product Name        Rating  \
# 0  Kadence Frontier guitar with Online Guitar lea...    4 out of 5
# 1  Kadence Frontier Jumbo Semi Acoustic Guitar Wi...    4 out of 5
# 2  Vault Traveller 34 Inch Acoustic Guitar With B...  3.9 out of 5
# 3  Blueberry 38C, 38" Acoustic Guitar Kit with Ba...  3.8 out of 5
# 4  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...    4 out of 5
#
#     No Of Ratings      Price     Return/Exchange Expected Delivery  \
# 0   1,481 ratings  ₹5,399.00  7 Days Replacement                 -
# 1   1,214 ratings  ₹7,348.00  7 Days Replacement                 -
# 2     342 ratings          -  7 Days Replacement                 -
# 3      14 ratings          -  7 Days Replacement                 -
# 4  15,861 ratings          -  7 Days Replacement                 -
#
#   Availability                                      Other Details  \
# 0            -  ★ Design - The High Gloss finish, Simple head ...
# 1            -  QUALITY STRINGS ---The surface is coated with ...
# 2            -  Size: 34" Steel stringed | Number of Strings: ...
# 3            -  Material: Top: linden wood, Side & Back: - lin...
# 4            -  Black Glossy Finish, Number of Frets: 18, Acou...
#
#                                          Product URL
# 0  https://www.amazon.in/gp/slredirect/picassoRed...
# 1  https://www.amazon.in/gp/slredirect/picassoRed...
# 2  https://www.amazon.in/gp/slredirect/picassoRed...
# 3  https://www.amazon.in/gp/slredirect/picassoRed...
# 4  https://www.amazon.in/Juarez-Acoustic-Cutaway-...

# %%
# Saving data in csv
Product.to_csv("Guitar.csv")

# %% [markdown]
# ## 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
# Connecting to the webdriver
driver = webdriver.Chrome("chromedriver.exe")
# Getting the webpage of mentioned url 
url = "https://images.google.com/"
#Creating empty list 
urls = []    #empty list
data = []    #empty list
search_item = ["fruits", "cars", "Machine Learning","Guitar","Cakes"]
for item in search_item:
    driver.get(url)  
    time.sleep(5)
    
    # Finding webelement for search_bar
    search_bar = driver.find_element_by_tag_name("input") 
    
    # Sending keys to get the keyword for search bar
    search_bar.send_keys(str(item))
    
    # Clicking on search button
    search_button =driver.find_element_by_xpath("//button[@class='Tg7LZd']").click()
    
    # Scrolling down the webpage to get some more images
    for _ in range(500):
        driver.execute_script("window.scrollBy(0,10)")
        
        imgs = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:10]:
        urls.append(i)
                    
for i in range(len(urls)):
    if i >= 50:
        break
    print("Downloading {0} of {1} images" .format(i, 50))
    response = requests.get(urls[i])

    file = open(r"C:\Users\X1\images\images"+str(i)+".jpg", "wb")

    file.write(response.content)
# Out:
# Downloading 0 of 50 images
# Downloading 1 of 50 images
# Downloading 2 of 50 images
# Downloading 3 of 50 images
# Downloading 4 of 50 images
# Downloading 5 of 50 images
# Downloading 6 of 50 images
# Downloading 7 of 50 images
# Downloading 8 of 50 images
# Downloading 9 of 50 images
# Downloading 10 of 50 images
# Downloading 11 of 50 images
# Downloading 12 of 50 images
# Downloading 13 of 50 images
# Downloading 14 of 50 images
# Downloading 15 of 50 images
# Downloading 16 of 50 images
# Downloading 17 of 50 images
# Downloading 18 of 50 images
# Downloading 19 of 50 images
# Downloading 20 of 50 images
# Downloading 21 of 50 images
# Downloading 22 of 50 images
# Downloading 23 of 50 images
# Downloading 24 of 50 images
# Downloading 25 of 50 images
# Downloading 26 of 50 images
# Downloading 27 of 50 images
# Downloading 28 of 50 images
# Downloading 29 of 50 images
# Downloading 30 of 50 images
# Downloading 31 of 50 images
# Downloading 32 of 50 images
# Downloading 33 of 50 images
# Downloading 34 of 50 images
# Downloading 35 of 50 images
# Downloading 36 of 50 images
# Downloading 37 of 50 images
# Downloading 38 of 50 images
# Downloading 39 of 50 images
# Downloading 40 of 50 images
# Downloading 41 of 50 images
# Downloading 42 of 50 images
# Downloading 43 of 50 images
# Downloading 44 of 50 images
# Downloading 45 of 50 images
# Downloading 46 of 50 images
# Downloading 47 of 50 images
# Downloading 48 of 50 images
# Downloading 49 of 50 images

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#Lets connect to the web driver
driver=webdriver.Chrome(r"C:\Users\X1\chromedriver_win32\chromedriver.exe")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.flipkart.com/')

# %%
# Closing Login popup button
login_X_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()

# %%
# Searching for web element
search_bar = driver.find_element_by_xpath("//input[@class='_3704LK']")
# Sending keys to search product
search_bar.send_keys("pixel 4A")

# %%
# Locating the search button using xpath
search_btn = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
# Clicking on search button
search_btn.click()

# %%
# Fetching 1st page URLs of smartphone
page1_url = []   #empty list
urls = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for url in urls:
    page1_url.append(url.get_attribute('href'))

# %%
len(page1_url)
# Out:
# 24

# %%
# Creating Empty lists for required atrributes

Smartphones = {}
Smartphones["Brand"] = []
Smartphones["Phone name"] = []
Smartphones["Colour"] = []
Smartphones["RAM"] = []
Smartphones["Storage(ROM)"] = []
Smartphones["Primary Camera"] = []
Smartphones["Secondary Camera"] = []
Smartphones["Display Size"] = []
Smartphones["Battery Capacity"] = []
Smartphones["Price"] = []
Smartphones["Product_URL"] = []

# %%
# Scraping data from each url of page 1
for url in page1_url:
    driver.get(url)                                                        
    print("Scraping URL = ", url)
    Smartphones['Product_URL'].append(url)                                                          
    time.sleep(2)
    
    
    #Clicking on read more button to get more information
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
    
    
    #Scraping brand name of smartphone
    try:
        brand_tags = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      
        Smartphones["Brand"].append(brand_tags.text.split()[0])
    except NoSuchElementException:
        Smartphones['Brand'].append('-')
    
    
    #Scraping name of smartphone
    try:
        name_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')     
        Smartphones['Phone name'].append(name_tags.text)
    except NoSuchElementException:
        Smartphones['Phone name'].append('-')
    
    
    #Scraping colour of smartphone
    try:
        color_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      
        Smartphones['Colour'].append(color_tags.text)
    except NoSuchElementException:
        Smartphones['Colour'].append('-')
     
    
    #Scraping RAM data of smartphone
    try:
        ram_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                
        Smartphones['RAM'].append(ram_tags.text)
    except NoSuchElementException:
        Smartphones['RAM'].append('-')
    
    
    #Scraping ROM data of smartphone
    try:
        rom_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')        
        Smartphones['Storage(ROM)'].append(rom_tags.text)
    except NoSuchElementException:
        Smartphones['Storage(ROM)'].append('-')
        
        
    #Scraping Primary camera data of smartphone
    try:                                                                                    
        pri_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')
        Smartphones['Primary Camera'].append(pri_tags.text)
    except NoSuchElementException:
        Smartphones['Primary Camera'].append('-')
        
        
    #Scraping secondary camera data of smarphone
    try:                                                                                    
        sec_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
        if sec_tags != "Secondary Camera" : 
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
                sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
        Smartphones['Secondary Camera'].append(sec_cam.text)
    except NoSuchElementException:
        Smartphones['Secondary Camera'].append('-')
        
        
    #Scraping Display size data of smartpone
    try:
        disp_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
        if disp_tags.text != "Display Features" : raise NoSuchElementException
        disp_size = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  
        Smartphones['Display Size'].append(disp_size.text)
    except NoSuchElementException:
        Smartphones['Display Size'].append('-')
    
    
    #Scraping battery capacity of smartphone
    try:
        if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')              
        Smartphones['Battery Capacity'].append(bat_capa.text)
    except NoSuchElementException:
        Smartphones['Battery Capacity'].append('-')
        
        
        
    #Scraping Price of smartphone
    try:
        price_tags = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')      
        Smartphones['Price'].append(price_tags.text)
    except NoSuchElementException:
        Smartphones['Price'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHV86NZHMDM&lid=LSTMOBGDRHV86NZHMDMR0BLSS&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHV86NZHMDM.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHNBBBBP5&lid=LSTMOBGDRHVHNBBBBP57SXRTY&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVHNBBBBP5.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHYFKQP8K&lid=LSTMOBGDRHVHYFKQP8KYHDDNN&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVHYFKQP8K.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVMW2UDXZY&lid=LSTMOBGDRHVMW2UDXZYRBYUFR&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVMW2UDXZY.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVWJUFTYQJ&lid=LSTMOBGDRHVWJUFTYQJ7NGITG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVWJUFTYQJ.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVXFVCGS23&lid=LSTMOBGDRHVXFVCGS23RDLBPG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVXFVCGS23.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVZN29ZJF4&lid=LSTMOBGDRHVZN29ZJF4QSKOSJ&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVZN29ZJF4.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDC6HFGCW5PGF.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10a-slate-grey-32-gb/p/itm755830dd54ae1?pid=MOBGDRGQXGRHUJS2&lid=LSTMOBGDRGQXGRHUJS2YKYJT7&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRGQXGRHUJS2.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-metallic-blue-32-gb/p/itm53bc6ebfe147b?pid=MOBG7H8GFGZPYUFH&lid=LSTMOBG7H8GFGZPYUFH8RDQ6A&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBG7H8GFGZPYUFH.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-polar-black-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HZHYVX96A&lid=LSTMOBGDC6HZHYVX96AHNLOZE&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDC6HZHYVX96A.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJZZRCJ3XHG&lid=LSTMOBG7CJZZRCJ3XHGG7UNWC&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBG7CJZZRCJ3XHG.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-pro-5g-turbo-cyan-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHVRHDZCJ4Q&lid=LSTMOBGDRHVRHDZCJ4QOKUEEL&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVRHDZCJ4Q.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10a-slate-grey-64-gb/p/itm755830dd54ae1?pid=MOBGDRGV2UAGZYZG&lid=LSTMOBGDRGV2UAGZYZGOV9P34&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRGV2UAGZYZG.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10a-sea-blue-64-gb/p/itm755830dd54ae1?pid=MOBGDRGY2TNHJQTW&lid=LSTMOBGDRGY2TNHJQTWJANWMK&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRGY2TNHJQTW.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-pro-5g-turbo-black-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHV9AZEZTN7&lid=LSTMOBGDRHV9AZEZTN7WV8UBJ&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHV9AZEZTN7.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-pro-5g-turbo-cyan-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHVYUZFQEDE&lid=LSTMOBGDRHVYUZFQEDEL4F8JS&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVYUZFQEDE.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CHHZ2MUWAZ4&lid=LSTMOBG7CHHZ2MUWAZ4YGHQDE&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBG7CHHZ2MUWAZ4.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-y21g-midnight-blue-64-gb/p/itmcb4986f752d3d?pid=MOBGD6DG7HXHP4KP&lid=LSTMOBGD6DG7HXHP4KPDTSFLP&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGD6DG7HXHP4KP.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJMHFQJFCX3&lid=LSTMOBG7CJMHFQJFCX3TCC7KY&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBG7CJMHFQJFCX3.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7DGGNP5N2RXH&lid=LSTMOBG7DGGNP5N2RXH7DCWRL&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBG7DGGNP5N2RXH.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-pro-5g-turbo-black-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHVT8RAZDYR&lid=LSTMOBGDRHVT8RAZDYR52GVHN&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGDRHVT8RAZDYR.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-note-11-space-black-128-gb/p/itm2a388ca843b21?pid=MOBGBHCK9HJQZNBK&lid=LSTMOBGBHCK9HJQZNBKNSPBNP&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=0e9795d1-803d-45b3-bb27-c417ce35fbcf.MOBGBHCK9HJQZNBK.SEARCH&ppt=hp&ppn=homepage&ssid=vmtjw2fmm80000001653196900571&qH=9b26a23b2cff510d

# %%
#Checking lengths of all scraped data
print(len(Smartphones["Brand"]), len(Smartphones["Phone name"]), len(Smartphones["Colour"]), len(Smartphones["RAM"]), len(Smartphones["Storage(ROM)"]), len(Smartphones["Primary Camera"]), len(Smartphones["Secondary Camera"]), len(Smartphones["Display Size"]), len(Smartphones["Battery Capacity"]), len(Smartphones["Price"]), len(Smartphones['Product_URL']))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame.from_dict(Smartphones)
df
# Out:
#       Brand      Phone name           Colour   RAM Storage(ROM)  \
# 0    Google        Pixel 4a       Just Black  6 GB       128 GB
# 1      vivo          T1 44W         Ice Dawn  8 GB       128 GB
# 2      vivo          T1 44W       Starry Sky  4 GB       128 GB
# 3      vivo          T1 44W       Starry Sky  8 GB       128 GB
# 4      vivo          T1 44W       Starry Sky  6 GB       128 GB
# 5      vivo          T1 44W  Midnight Galaxy  8 GB       128 GB
# 6      vivo          T1 44W  Midnight Galaxy  6 GB       128 GB
# 7      vivo          T1 44W  Midnight Galaxy  4 GB       128 GB
# 8   Infinix         Smart 6    Starry Purple  2 GB        64 GB
# 9     REDMI       REDMI 10A       Slate Grey  3 GB        32 GB
# 10    Redmi  Redmi 9A Sport    Metallic Blue  3 GB        32 GB
# 11  Infinix         Smart 6      Polar Black  2 GB        64 GB
# 12    Redmi  Redmi 9A Sport      Coral Green  3 GB        32 GB
# 13     vivo       T1 Pro 5G       Turbo Cyan  8 GB       128 GB
# 14    REDMI       REDMI 10A       Slate grey  4 GB        64 GB
# 15    REDMI       REDMI 10A         Sea Blue  4 GB        64 GB
# 16     vivo       T1 Pro 5G      Turbo Black  8 GB       128 GB
# 17     vivo       T1 Pro 5G       Turbo Cyan  6 GB       128 GB
# 18    Redmi  Redmi 9A Sport      Coral Green  2 GB        32 GB
# 19     vivo            Y21G    Midnight Blue  4 GB        64 GB
# 20    Redmi  Redmi 9A Sport     Carbon Black  3 GB        32 GB
# 21    Redmi  Redmi 9A Sport     Carbon Black  2 GB        32 GB
# 22     vivo       T1 Pro 5G      Turbo Black  6 GB       128 GB
# 23    Redmi   Redmi Note 11      Space Black  6 GB       128 GB
#
#         Primary Camera   Secondary Camera          Display Size  \
# 0   12.2MP Rear Camera   8MP Front Camera  14.76 cm (5.81 inch)
# 1     50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 2     50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 3     50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 4     50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 5     50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 6     50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 7     50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 8    8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 9       Primary Camera                  -  16.59 cm (6.53 inch)
# 10    13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 11   8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 12    13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 13    64MP + 8MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 14    13MP Rear Camera                  -  16.59 cm (6.53 inch)
# 15      Primary Camera                  -  16.59 cm (6.53 inch)
# 16    64MP + 8MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 17    64MP + 8MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 18    13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 19          13MP + 2MP   8MP Front Camera  16.54 cm (6.51 inch)
# 20    13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 21    13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 22    64MP + 8MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 23      Primary Camera                  -  16.33 cm (6.43 inch)
#
#    Battery Capacity    Price  \
# 0          3140 mAh  ₹31,999
# 1          5000 mAh  ₹17,999
# 2          5000 mAh  ₹14,499
# 3          5000 mAh  ₹17,999
# 4          5000 mAh  ₹15,999
# 5          5000 mAh  ₹17,999
# 6          5000 mAh  ₹15,999
# 7          5000 mAh  ₹14,499
# 8          5000 mAh   ₹7,499
# 9                 -   ₹8,790
# 10         5000 mAh   ₹7,973
# 11         5000 mAh   ₹7,499
# 12         5000 mAh   ₹7,988
# 13         4700 mAh  ₹24,999
# 14         5000 mAh   ₹9,511
# 15                -   ₹9,627
# 16         4700 mAh  ₹24,999
# 17         4700 mAh  ₹23,999
# 18         5000 mAh   ₹7,068
# 19         5000 mAh  ₹13,499
# 20         5000 mAh   ₹7,747
# 21         5000 mAh   ₹6,953
# 22         4700 mAh  ₹23,999
# 23                -  ₹15,745
#
#                                           Product_URL
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 2   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 3   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 4   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 5   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 6   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 7   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 8   https://www.flipkart.com/infinix-smart-6-starr...
# 9   https://www.flipkart.com/redmi-10a-slate-grey-...
# 10  https://www.flipkart.com/redmi-9a-sport-metall...
# 11  https://www.flipkart.com/infinix-smart-6-polar...
# 12  https://www.flipkart.com/redmi-9a-sport-coral-...
# 13  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 14  https://www.flipkart.com/redmi-10a-slate-grey-...
# 15  https://www.flipkart.com/redmi-10a-sea-blue-64...
# 16  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 17  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 18  https://www.flipkart.com/redmi-9a-sport-coral-...
# 19  https://www.flipkart.com/vivo-y21g-midnight-bl...
# 20  https://www.flipkart.com/redmi-9a-sport-carbon...
# 21  https://www.flipkart.com/redmi-9a-sport-carbon...
# 22  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 23  https://www.flipkart.com/redmi-note-11-space-b...

# %% [markdown]
# ## 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps

# %%
# Connecting to the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# Getting mentioned url and opening google maps web page
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)

# %%
# entering the city name in search bar 
City = input('Enter City name that has to be searched : ')
search_bar = driver.find_element_by_id("searchboxinput")                       
search_bar.clear()                                                             
time.sleep(2)
# Out:
# Enter City name that has to be searched : Bangalore

# %%
# Sending keys to find cities
search_bar.send_keys(City)

# %%
# Checking for webelement and Clicking on search button
search_btn = driver.find_element_by_id("searchbox-searchbutton")              
search_btn.click()                                                             
time.sleep(2)

# %%
try:
    url_str = driver.current_url
    print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/Bengaluru,+Karnataka/@13.0834381,77.0109261,364114m/data=!3m1!1e3!4m5!3m4!1s0x3bae1670c9b44e6d:0xf8dfc3e8517e4fe0!8m2!3d12.9715987!4d77.5945627
# Latitude = 13.0834381, Longitude = 77.0109261

# %% [markdown]
# ## 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
# Connecting to the web driver
driver=webdriver.Chrome("chromedriver.exe") 

# opening the url track.in
url = "https://trak.in/"
driver.get(url)
time.sleep(2)

# %%
#Getting xpath for funding deals and clicking on the button
fund_button = driver.find_element_by_xpath("//li[@class='menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-51510']")
print(fund_button)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5d7588eff77337f72fa3b299b17b93bf", element="43538f5d-09d0-46cc-bfdf-b689773be8c2")>

# %%
#Creating Empty lists
fund_deals = {}
fund_deals['Date'] = []
fund_deals['Startup Name'] = []
fund_deals['Industry/Vertical'] = []
fund_deals['Sub-Vertical'] = []
fund_deals['Location'] = []
fund_deals['Investor'] = []
fund_deals['Investment Type'] = []
fund_deals['Amount(in USD)'] = []

# %%
for i in range(54,57):

    # Scraping data of Date
    date = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in date:
        fund_deals['Date'].append(d.text)
        
    # Scraping data of Startup Name
    startup_name= driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for name in startup_name:
        fund_deals['Startup Name'].append(name.text)
    
    # Scraping data of Industry OR Vertical
    industry = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for ind in industry:
        fund_deals['Industry/Vertical'].append(ind.text)
    
    # Scraping data of Sub-Vertical
    sub_vertical = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for sv in sub_vertical:
        fund_deals['Sub-Vertical'].append(sv.text)

    # Scraping data of Location
    location = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for loc in location:
        fund_deals['Location'].append(loc.text)
    
    # Scraping data of Investor
    investor = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for invest in investor:
        fund_deals['Investor'].append(invest.text)
        
    # Scraping data of Investment Type
    investment_type = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for invtype in investment_type:
        fund_deals['Investment Type'].append(invtype.text)
        
    # Scraping data of Amount
    amount = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for amt in amount:
        fund_deals['Amount(in USD)'].append(amt.text)

# %%
# Creating DataFrame for scraped data
fund_data = pd.DataFrame(fund_deals)
fund_data
# Out:
#           Date            Startup Name       Industry/Vertical  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# 14  12/02/2021                 Grofers              E-Commerce
# 15  09/02/2021                 Nothing              Technology
# 16  09/02/2021             SplashLearn                  EdTech
# 17  15/01/2021         Digit Insurance      Financial Services
# 18  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 19  19/01/2021                  DeHaat        AgriTech Startup
# 20  19/01/2021               Darwinbox                    SaaS
# 21  18/01/2021                   mfine     Health Tech Startup
# 22  18/01/2021                   Udayy                  EdTech
# 23  11/01/2021           True Elements            Food Startup
# 24  13/01/2021                   Saveo          B2B E-commerce
# 25  11/02/2021                Doubtnut                Edu Tech
# 26  22/02/2021                  Zomato             Hospitality
# 27  19/02/2021               Fingerlix             Hospitality
# 28  17/02/2021                   Zolve                 FinTech
# 29  15/02/2021               KreditBee                 Finance
# 30  12/02/2021               Pepperfry              E-commerce
# 31  12/02/2021                 Grofers              E-Commerce
# 32  09/02/2021                 Nothing              Technology
# 33  09/02/2021             SplashLearn                  EdTech
# 34  04/03/2021               DealShare              E-commerce
# 35  31/03/2021                Uniphore              Technology
# 36  30/03/2021                   Dunzo              E-commerce
# 37  30/03/2021                  BYJU’S                Edu-tech
# 38  23/03/2021             SkilloVilla                Edu-tech
# 39  25/03/2021                CityMall              E-commerce
# 40  26/03/2021                   DotPe                 FinTech
#
#                                          Sub-Vertical           Location  \
# 0                                  Insurance Services          Bengaluru
# 1       Shave care, beard care, and skincare products          New Delhi
# 2   online marketplace for farm products and services              Patna
# 3                                             HR Tech             Mumbai
# 4                  AI-powered telemedicine mobile app          Bengaluru
# 5      Online learning platform for kids in class 1-5            Gurgaon
# 6                       Whole Food plant based Nashta               Pune
# 7                                          Pharmacies          Bengaluru
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                                 Insurance Services          Bengaluru
# 18      Shave care, beard care, and skincare products          New Delhi
# 19  online marketplace for farm products and services              Patna
# 20                                            HR Tech             Mumbai
# 21                 AI-powered telemedicine mobile app          Bengaluru
# 22     Online learning platform for kids in class 1-5            Gurgaon
# 23                      Whole Food plant based Nashta               Pune
# 24                                         Pharmacies          Bengaluru
# 25                                E-Learning Platform            Gurgaon
# 26                      Online Food Delivery Platform            Gurgaon
# 27                      Semi-cooked food delivery app             Mumbai
# 28                             Global Neobank Venture             Mumbai
# 29                           Digital lending platform          Bengaluru
# 30                        Multi-brand furniture brand             Mumbai
# 31                                 Online supermarket            Gurgaon
# 32                        Consumer Technology Venture             London
# 33                      Game-based learning programme            Gurgaon
# 34                           Online shopping platform  Jaipur, Rajasthan
# 35            Conversational Service Automation (CSA)          Palo Alto
# 36                           Hyper-local delivery app          Bengaluru
# 37                                    Online tutoring          Bengaluru
# 38                Career and job-oriented upskilling.          Bengaluru
# 39       Social ecommerce and online grocery platform            Gurgaon
# 40  Commerce and payments platform to offline ente...            Gurgaon
#
#                                              Investor Investment Type  \
# 0    A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                   Reckitt Benckiser         Venture
# 2                                     Prosus Ventures        Series C
# 3                                 Salesforce Ventures            Seed
# 4                          Heritas Capital Management   Venture Round
# 5                                     Sequoia Capital    Seed Funding
# 6                               SIDBI Venture Capital          Series
# 7           Matrix Partners India, RTP Global, others            Seed
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17   A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 18                                  Reckitt Benckiser         Venture
# 19                                    Prosus Ventures        Series C
# 20                                Salesforce Ventures            Seed
# 21                         Heritas Capital Management   Venture Round
# 22                                    Sequoia Capital    Seed Funding
# 23                              SIDBI Venture Capital          Series
# 24          Matrix Partners India, RTP Global, others            Seed
# 25  SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 26                                 Tiger Global, Kora         Venture
# 27           Rhodium Trust, Accel Partners and Swiggy        Series C
# 28     Accel Partners and Lightspeed Venture Partners            Seed
# 29  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 30                                    InnoVen Capital  Debt Financing
# 31                         SoftBank Vision Fund (SVF)     Unspecified
# 32                                                 GV        Series A
# 33                                       Owl Ventures        Series C
# 34                                    Innoven Capital  Debt Financing
# 35                          Sorenson Capital Partners        Series D
# 36                          Krishtal Advisors Pte Ltd        Series E
# 37         MC Global Edtech, B Capital, Baron, others        Series F
# 38                              Titan Capital, others            Seed
# 39                                     Accel Partners        Series A
# 40                                               PayU        Series A
#
#    Amount(in USD)
# 0     1,80,00,000
# 1    6,172,258.50
# 2      30,000,000
# 3      15,000,000
# 4      16,000,000
# 5      15,000,000
# 6     100,000,000
# 7       4,000,000
# 8       2,500,000
# 9     250,000,000
# 10   2,747,045.20
# 11    1,50,00,000
# 12     75,000,000
# 13      4,773,958
# 14     55,000,000
# 15     15,000,000
# 16     18,000,000
# 17    1,80,00,000
# 18   6,172,258.50
# 19     30,000,000
# 20     15,000,000
# 21     16,000,000
# 22     15,000,000
# 23    100,000,000
# 24      4,000,000
# 25      2,500,000
# 26    250,000,000
# 27   2,747,045.20
# 28    1,50,00,000
# 29     75,000,000
# 30      4,773,958
# 31     55,000,000
# 32     15,000,000
# 33     18,000,000
# 34    250,000,000
# 35    140,000,000
# 36      8,000,000
# 37    460,000,000
# 38    300,000,000
# 39     11,000,000
# 40     27,500,000

# %%
#Saving data in csv file
fund_data.to_csv("Funding_deals.csv")

# %% [markdown]
# ## 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# Connecting to the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# %%
# opening the url digit.in
url = "https://www.digit.in/"
driver.get(url)
time.sleep(2)

# %%
#searching for best laptop
best_gam_laptops = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

# %%
#Creating empty lists
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
Graph_proc = []
Price = []

# %%
# Scraping the data of laptop names
laptop_name= driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for name in laptop_name:
    Laptop_Name.append(name.text)
    
    
#Scraping the data of operating system
try:
    op_sys = driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display of the laptop
try:
    display= driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    processor = driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[4]/div/div")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass

#Scraping data of memory
try:
    memory = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass


#Scraping data of weight
try:
    weight = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for wgt in weight:
        Weight.append(wgt.text)
except NoSuchElementException:
    pass


#Scraping data of dimensions
try:
    dimension = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass


#Scraping data of Graph processor
try:
    graph = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[9]/td[3]")
    for gra in graph:
        Graph_proc.append(gra.text)
except NoSuchElementException:
    pass


#Scraping data of price
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
print(len(Laptop_Name),len(Operating_sys),len(Display),len(Processor),len(Memory),len(Weight),len(Dimensions),len(Graph_proc),len(Price))
# Out:
# 10 10 10 10 10 10 10 10 10

# %%
# Creating DataFrame for scraped data
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = Laptop_Name
Gaming_Laptop['Operating system'] = Operating_sys
Gaming_Laptop['Display'] = Display
Gaming_Laptop['Processor'] = Processor
Gaming_Laptop['Memory'] = Memory
Gaming_Laptop['Weight'] = Weight
Gaming_Laptop['Dimensions'] = Dimensions
Gaming_Laptop['Graphical Processor'] = Graph_proc
Gaming_Laptop['Price'] = Price
Gaming_Laptop
# Out:
#                    Laptop Name Operating system              Display  \
# 0              MSI RAIDER GE76  WINDOWS 11 HOME    17" (3840 X 2160)
# 1       ASUS ROG STRIX SCAR 15  WINDOWS 11 HOME  15.6" (2560 X 1440)
# 2                 ACER NITRO 5       WINDOWS 10  15.6" (1920 X 1080)
# 3              MSI STEALTH 15M       WINDOWS 10  15.6" (1920 X 1080)
# 4       ASUS ROG STRIX SCAR 15       WINDOWS 10  15.6" (2560 X 1440)
# 5       ASUS ROG STRIX SCAR 15  WINDOWS 10 HOME  15.6" (1920 X 1080)
# 6            ASUS ZEPHYRUS G14  WINDOWS 10 HOME    14" (1920 X 1080)
# 7                   HP OMEN 16  WINDOWS 11 HOME  16.1" (1920 X 1080)
# 8     ASUS ROG ZEPHYRUS DUO 15       WINDOWS 10  15.6" (3840 X 1100)
# 9  ACER ASPIRE 7 GAMING LAPTOP  WINDOWS 10 HOME  15.6" (1920 X 1080)
#
#                                   Processor                  Memory Weight  \
# 0    12TH GEN INTEL CORE I9-12900HK | 5 GHZ   2 TB SSD/16 GBGB DDR5    2.9
# 1   12TH GEN INTEL CORE I9-12900H | 2.5 GHZ   2 TB SSD/32 GBGB DDR5    2.3
# 2           AMD RYZEN 9 OCTA CORE | 2.4 GHZ   1 TB HDD/16 GBGB DDR4    2.4
# 3      INTEL CORE I7 11TH GEN - 11375H | NA   1 TB SSD/16 GBGB DDR4    1.7
# 4  AMD RYZEN 9 OCTA CORE - 5900HX | 3.3 GHZ   2 TB SSD/32 GBGB DDR4   2.30
# 5             AMD RYZEN™ 9 5900HX | 3.3 GHZ   1 TB SSD/16 GBGB DDR4   2.30
# 6             AMD 3RD GEN RYZEN 9 | 3.3 GHZ   1 TB SSD/16 GBGB DDR4   1.65
# 7   12TH GEN INTEL CORE I7-12700H | 4.7 GHZ   1 TB SSD/16 GBGB DDR4   2.32
# 8        INTEL CORE I7 10TH GEN 10875H | NA  512 GB SSD/4 GBGB DDR4    2.4
# 9         AMD RYZEN™ 5-5500U HEXA-CORE | NA  512 GB SSD/8 GBGB DDR4   2.15
#
#                 Dimensions            Graphical Processor        Price
# 0           397 x 284 x 26      NVIDIA GeForce RTX 3080Ti  Rs  429,940
# 1           259 x 354 x 27     NVIDIA GeForce RTX 3070 Ti  Rs  285,390
# 2       363.4 x 255 x 23.9        NVIDIA GeForce RTX 3070  Rs  129,990
# 3      358.3 x 248 x 16.15        NVIDIA GeForce RTX 3060  Rs  134,990
# 4         354 x 259 x 22.6        NVIDIA GeForce RTX 3080  Rs  193,990
# 5       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070  Rs  215,990
# 6        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060  Rs  144,990
# 7       36.92 x 24.8 x 2.3        NVIDIA GeForce RTX 3060  Rs  139,990
# 8  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q  Rs  185,000
# 9       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650   Rs  53,490

# %% [markdown]
# ## 8. Write a python program to scrape the details for all billionaires from www.forbes.com.
# Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry

# %%
# Connecting to the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

#Getting the specified url
url = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url)
time.sleep(3)

#clicking on the explore button
button = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
button.click()
time.sleep(1)

#select billionaire  
billionaires = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
billionaires.click()
time.sleep(1)

#select world billionaire  
world_bill= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill.click()
time.sleep(1)

# %%
#Scraping required data from the web page
#Creating empty lists
Rank = []
Person_Name = []
total_net_worth = []
Age = []
citizenship = []
Source = []
industry = []

# %%
#Scraping required data running on while loop
while(True):
    #Scraping the data of rank of the billionaires
    rank_tags= driver.find_elements_by_xpath("//div[@class='rank']")
    for rank in rank_tags:
        Rank.append(rank.text)
    time.sleep(1)
    
    
    #Scraping the data of names of the billionaires
    name_tags= driver.find_elements_by_xpath("//div[@class='personName']/div")
    for name in name_tags:
        Person_Name.append(name.text)
    time.sleep(1)
    
    
    #Scraping data of age of the billionaires
    age_tags= driver.find_elements_by_xpath("//div[@class='age']/div")
    for age in age_tags:
        Age.append(age.text)   
    time.sleep(1)
    
    
    #Scraping data of citizenship of the billionaires
    cit_tags= driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for cit in cit_tags:
        citizenship.append(cit.text)
    time.sleep(1)
    
    
    #Scraping data of source of income of the billionaires
    sour_tags= driver.find_elements_by_xpath("//div[@class='source']")
    for sour in sour_tags:
        Source.append(sour.text)    
    time.sleep(1)
    
    
    #Scraping data of Industry of the billionaires
    ind_tags= driver.find_elements_by_xpath("//div[@class='category']//div")
    for ind in ind_tags:
        industry.append(ind.text)
        
        
    #scraping data of net_worth of billionaires
    net_tags= driver.find_elements_by_xpath("//div[@class='netWorth']//div[1]")
    for net in net_tags:
        total_net_worth.append(net.text)
    time.sleep(1)
    
    
    #Clicking on next button
    try:
        next_button = driver.find_element_by_xpath("//button[@class='pagination-btn pagination-btn--next ']")
        next_button.click()
    except:
        break
        
#Scraping data of net worth
Net_Worth = []
for i in range(0,len(total_net_worth),2):
    Net_Worth.append(total_net_worth[i])
    
time.sleep(2)

# %%
#Framing data
Billionaires=pd.DataFrame({})
Billionaires['Rank'] = Rank
Billionaires['Names'] = Person_Name
Billionaires['Net Worth'] = Net_Worth
Billionaires['Age'] = Age
Billionaires['Citizenship'] = citizenship
Billionaires['Source'] = Source
Billionaires['Industry'] = industry
Billionaires
# Out:
#      Rank                     Names Net Worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %% [markdown]
# ## 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
#Lets connect to the web driver
driver=webdriver.Chrome(r"C:\Users\X1\chromedriver_win32\chromedriver.exe")

# %%
driver=webdriver.Chrome('chromedriver.exe')
time.sleep(2)
#time.sleep will ask the browser to wait for 2 sec and then run

# %%
driver.get('https://www.youtube.com/')

# %%
#Finding element for job search bar
search_field_designation=driver.find_element_by_class_name("style-scope ytd-searchbox") # job search bar
search_field_designation.send_keys("Our Planet")

#clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn.click()
time.sleep(1)

# %%
#Clicking on first video
video = driver.find_element_by_xpath("//yt-formatted-string[@class='style-scope ytd-video-renderer']")
video.click()

# %%
# 1000 time we scroll down by 10000 in order to generate more Comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
#Creating empty lists
comments = []
comment_time = []
Likes = []
No_of_Likes = []

# %%
#scrape comments
cm = driver.find_elements_by_xpath("//yt-formatted-string[@class ='style-scope ytd-comment-renderer']")
for i in cm:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)
time.sleep(5)


# scrape time when comment was posted
tm = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")
for i in tm:
    if i.text is None:
        comment_time.append("--")
    else:
        comment_time.append(i.text)
time.sleep(5)

for i in range(0,len(comment_time),2):
    comment_time.append(comment_time[i])
time.sleep(5)
    
# scrape the comment likes
like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    if i.text is None:
        Likes.append("--")
    else:
        Likes.append(i.text)
    
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])

# %%
print(len(comments),len(comment_time),len(No_of_Likes))
# Out:
# 2160 810 3600

# %%
#Creating dataframe for scraped data

Youtube=pd.DataFrame({})
Youtube['Comments'] = comments[0:500]
Youtube['Comment upvotes'] = No_of_Likes[0:500]
Youtube['Time'] = comment_time[0:500]
Youtube
# Out:
#                                               Comments Comment upvotes  \
# 0                                                                  565
# 1    i watched behind the scenes of this series on ...             519
# 2                                                                  116
# 3    Mad respect to the cameraman who held his brea...              83
# 4                                                                  466
# ..                                                 ...             ...
# 495  ok I gotta admit that was amazing and the sand...               1
# 496
# 497  Ohh mehn you need to see the anticipation on m...
# 498                                                                 11
# 499  This man's voice is very soothing.  Thank you ...               7
#
#                      Time
# 0    2 years ago (edited)
# 1           11 months ago
# 2              1 year ago
# 3              1 year ago
# 4              3 days ago
# ..                    ...
# 495         11 months ago
# 496          4 months ago
# 497          5 months ago
# 498           2 years ago
# 499          5 months ago
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Q10: Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Connecting to the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Getting the web page of mentioned url
url = "https://www.hostelworld.com/"
driver.get(url)
time.sleep(5)

# %%
#locating the location search bar
search_bar = driver.find_element_by_id('location-text-input-field')

# Entering Lonodn in search bar
search_bar.send_keys("London,England")
time.sleep(3)

# %%
#Select london
search_button = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/div/input')
# Clicking on the button
search_button.click()
time.sleep(3)

# %%
#lets find required data
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

# %%
#Scraping hostel name
try:
    name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
    for i in name:
        hostel_name.append(i.text)
except NoSuchElementException:
    hostel_name.append('-')

# %%
hostel_name
# Out:
# ["St Christopher's Village",
#  'Palmers Lodge - Swiss Cottage',
#  'Generator London',
#  'Urbany Hostel London',
#  'Safestay London Elephant & Castle',
#  'No.8 Willesden Hostel London',
#  'No.8 Seven Sisters',
#  'London Backpackers',
#  'Safestay London Kensington Holland Park',
#  'Phoenix Hostel',
#  'Queen Elizabeth Chelsea',
#  'NX London Hostel',
#  'Hostel One Notting Hill',
#  "St Christopher's Hammersmith",
#  "St Christopher's Camden",
#  "St Christopher's Inn - Liverpool Street",
#  "St Christopher's Greenwich",
#  'PubLove @ The Steam Engine, Waterloo',
#  "St Christopher's Shepherds Bush",
#  'Selina Camden',
#  'PubLove @ The Crown, Battersea',
#  'Saint James Backpackers',
#  'PubLove @ The Green Man, Paddington',
#  'Chester Hotel Victoria',
#  'Britannia Inn Hotel',
#  'Barry House',
#  'London House Hotel',
#  'Elmwood Hotel',
#  'The W14 Hotel & Bar',
#  'Cranbrook Hotel']

# %%
len(hostel_name)
# Out:
# 30

# %%
 #Scraping distance from city centre
try:
    dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
    for i in dist:
        distance.append(i.text.replace('Hostel - ',''))
except NoSuchElementException:
    distance.append('-')

# %%
distance
# Out:
# ['1.8km from city centre',
#  '6.5km from city centre',
#  '3km from city centre',
#  '5.4km from city centre',
#  '1.7km from city centre',
#  '10km from city centre',
#  '9km from city centre',
#  '11.9km from city centre',
#  '5.9km from city centre',
#  '4.2km from city centre',
#  '5.7km from city centre',
#  '6.1km from city centre',
#  '5.5km from city centre',
#  '7.5km from city centre',
#  '4.3km from city centre',
#  '3.2km from city centre',
#  '7.6km from city centre',
#  '0.5km from city centre',
#  '7km from city centre',
#  '5.5km from city centre',
#  '4.7km from city centre',
#  '5.5km from city centre',
#  '4.3km from city centre',
#  'Hotel - 1.9km from city centre',
#  'Hotel - 14.5km from city centre',
#  'Bed and Breakfast - 4.2km from city centre',
#  'Hotel - 5.3km from city centre',
#  'Hotel - 3.2km from city centre',
#  'Hotel - 6.5km from city centre',
#  'Hotel - 14.8km from city centre']

# %%
len(distance)
# Out:
# 30

# %%
#Scraping privates from price
for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
    try:
        pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
        pvt_prices.append(pvt_price.text)
    except NoSuchElementException:
        pvt_prices.append('-')

# %%
 pvt_prices
# Out:
# ['Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723',
#  'Rs15248.02 Rs13723']

# %%
len(pvt_prices)
# Out:
# 30

# %%
#Scraping dorms price
for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
    try:
        dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
        dorms_price.append(dorms.text)
    except NoSuchElementException:
        dorms_price.append('-')

# %%
dorms_price
# Out:
# ['Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936',
#  'Rs3261.78 Rs2936']

# %%
len(dorms_price)
# Out:
# 30

# %%
#Scraping facilities
try:
    fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
    fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
    for i in fac1:
        for j in fac2:
            facilities.append(i.text +', '+ j.text )
except NoSuchElementException:
    facilities.append('-')

# %%
facilities
# Out:
# ['Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance']

# %%
#Fetching url of each hostel
p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
for i in p_url:
    product_url.append(i.get_attribute('href'))

# %%
product_url
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Palmers-Lodge-Swiss-Cottage/London/14348?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Willesden-Hostel-London/London/18420?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Seven-Sisters/London/91108?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Backpackers/London/527?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Kensington-Holland-Park/London/93920?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Phoenix-Hostel/London/48221?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Queen-Elizabeth-Chelsea/London/50443?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/NX-London-Hostel/London/15204?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hostel-One-Notting-Hill/London/291433?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Hammersmith/London/20976?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Camden/London/505?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Inn-Liverpool-Street/London/271698?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Greenwich/London/501?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Steam-Engine-Waterloo/London/29389?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Shepherds-Bush/London/506?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Selina-Camden/London/310274?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Crown-Battersea/London/60336?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Saint-James-Backpackers/London/70909?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Green-Man-Paddington/London/21953?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Chester-Hotel-Victoria/London/24750?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Britannia-Inn-Hotel/London/47955?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Barry-House/London/287321?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-House-Hotel/London/529?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Elmwood-Hotel/London/34338?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/The-W14-Hotel-Bar/London/50220?from=2022-06-04&to=2022-06-07&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Cranbrook-Hotel/London/10144?from=2022-06-04&to=2022-06-07&guests=2']

# %%
len(product_url)
# Out:
# 30

# %%
#Creating dataframe
Hostels = pd.DataFrame({})
Hostels['product_url'] = product_url
Hostels['Hostel_Name'] = hostel_name
Hostels['Distance fron city centre'] = distance
Hostels['Privates from price'] = pvt_prices
Hostels['Dorms from price'] = dorms_price
Hostels['Facilities'] = facilities[0:30]

Hostels
# Out:
#                                           product_url  \
# 0   https://www.hostelworld.com/pwa/hosteldetails....
# 1   https://www.hostelworld.com/pwa/hosteldetails....
# 2   https://www.hostelworld.com/pwa/hosteldetails....
# 3   https://www.hostelworld.com/pwa/hosteldetails....
# 4   https://www.hostelworld.com/pwa/hosteldetails....
# 5   https://www.hostelworld.com/pwa/hosteldetails....
# 6   https://www.hostelworld.com/pwa/hosteldetails....
# 7   https://www.hostelworld.com/pwa/hosteldetails....
# 8   https://www.hostelworld.com/pwa/hosteldetails....
# 9   https://www.hostelworld.com/pwa/hosteldetails....
# 10  https://www.hostelworld.com/pwa/hosteldetails....
# 11  https://www.hostelworld.com/pwa/hosteldetails....
# 12  https://www.hostelworld.com/pwa/hosteldetails....
# 13  https://www.hostelworld.com/pwa/hosteldetails....
# 14  https://www.hostelworld.com/pwa/hosteldetails....
# 15  https://www.hostelworld.com/pwa/hosteldetails....
# 16  https://www.hostelworld.com/pwa/hosteldetails....
# 17  https://www.hostelworld.com/pwa/hosteldetails....
# 18  https://www.hostelworld.com/pwa/hosteldetails....
# 19  https://www.hostelworld.com/pwa/hosteldetails....
# 20  https://www.hostelworld.com/pwa/hosteldetails....
# 21  https://www.hostelworld.com/pwa/hosteldetails....
# 22  https://www.hostelworld.com/pwa/hosteldetails....
# 23  https://www.hostelworld.com/pwa/hosteldetails....
# 24  https://www.hostelworld.com/pwa/hosteldetails....
# 25  https://www.hostelworld.com/pwa/hosteldetails....
# 26  https://www.hostelworld.com/pwa/hosteldetails....
# 27  https://www.hostelworld.com/pwa/hosteldetails....
# 28  https://www.hostelworld.com/pwa/hosteldetails....
# 29  https://www.hostelworld.com/pwa/hosteldetails....
#
#                                 Hostel_Name  \
# 0                  St Christopher's Village
# 1             Palmers Lodge - Swiss Cottage
# 2                          Generator London
# 3                      Urbany Hostel London
# 4         Safestay London Elephant & Castle
# 5              No.8 Willesden Hostel London
# 6                        No.8 Seven Sisters
# 7                        London Backpackers
# 8   Safestay London Kensington Holland Park
# 9                            Phoenix Hostel
# 10                  Queen Elizabeth Chelsea
# 11                         NX London Hostel
# 12                  Hostel One Notting Hill
# 13             St Christopher's Hammersmith
# 14                  St Christopher's Camden
# 15  St Christopher's Inn - Liverpool Street
# 16               St Christopher's Greenwich
# 17     PubLove @ The Steam Engine, Waterloo
# 18          St Christopher's Shepherds Bush
# 19                            Selina Camden
# 20           PubLove @ The Crown, Battersea
# 21                  Saint James Backpackers
# 22      PubLove @ The Green Man, Paddington
# 23                   Chester Hotel Victoria
# 24                      Britannia Inn Hotel
# 25                              Barry House
# 26                       London House Hotel
# 27                            Elmwood Hotel
# 28                      The W14 Hotel & Bar
# 29                          Cranbrook Hotel
#
#                      Distance fron city centre Privates from price  \
# 0                       1.8km from city centre  Rs15248.02 Rs13723
# 1                       6.5km from city centre  Rs15248.02 Rs13723
# 2                         3km from city centre  Rs15248.02 Rs13723
# 3                       5.4km from city centre  Rs15248.02 Rs13723
# 4                       1.7km from city centre  Rs15248.02 Rs13723
# 5                        10km from city centre  Rs15248.02 Rs13723
# 6                         9km from city centre  Rs15248.02 Rs13723
# 7                      11.9km from city centre  Rs15248.02 Rs13723
# 8                       5.9km from city centre  Rs15248.02 Rs13723
# 9                       4.2km from city centre  Rs15248.02 Rs13723
# 10                      5.7km from city centre  Rs15248.02 Rs13723
# 11                      6.1km from city centre  Rs15248.02 Rs13723
# 12                      5.5km from city centre  Rs15248.02 Rs13723
# 13                      7.5km from city centre  Rs15248.02 Rs13723
# 14                      4.3km from city centre  Rs15248.02 Rs13723
# 15                      3.2km from city centre  Rs15248.02 Rs13723
# 16                      7.6km from city centre  Rs15248.02 Rs13723
# 17                      0.5km from city centre  Rs15248.02 Rs13723
# 18                        7km from city centre  Rs15248.02 Rs13723
# 19                      5.5km from city centre  Rs15248.02 Rs13723
# 20                      4.7km from city centre  Rs15248.02 Rs13723
# 21                      5.5km from city centre  Rs15248.02 Rs13723
# 22                      4.3km from city centre  Rs15248.02 Rs13723
# 23              Hotel - 1.9km from city centre  Rs15248.02 Rs13723
# 24             Hotel - 14.5km from city centre  Rs15248.02 Rs13723
# 25  Bed and Breakfast - 4.2km from city centre  Rs15248.02 Rs13723
# 26              Hotel - 5.3km from city centre  Rs15248.02 Rs13723
# 27              Hotel - 3.2km from city centre  Rs15248.02 Rs13723
# 28              Hotel - 6.5km from city centre  Rs15248.02 Rs13723
# 29             Hotel - 14.8km from city centre  Rs15248.02 Rs13723
#
#     Dorms from price                                       Facilities
# 0   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 1   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 2   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 3   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 4   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 5   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 6   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 7   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 8   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 9   Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 10  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 11  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 12  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 13  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 14  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 15  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 16  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 17  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 18  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 19  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 20  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 21  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 22  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 23  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 24  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 25  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 26  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 27  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 28  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
# 29  Rs3261.78 Rs2936  Free WiFi, Follows Covid-19 sanitation guidance
